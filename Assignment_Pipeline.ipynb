# %%
import numpy as np
import pandas as pd
import plotly.express as px
from datetime import date,datetime, timedelta
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import statsmodels.api as sm
import statsmodels.formula.api as smf
import calendar

# %%
df=pd.read_csv('https://raw.githubusercontent.com/andreapiemmi/RepoTransactions_Case/main/repo_trades.csv',sep=';')
df[df.columns[['Date' in c for c in df.columns]]]=df.loc[:,['Date' in c for c in df.columns]].apply(
    lambda x: pd.to_datetime(x.str.replace('.','-',regex=True)),axis=0)
df=df.sort_values(by=['BusinessDate','PurchaseDate']).reset_index(drop=True)
#df

# %% [markdown]
# # Question 1

# %%
d1=pd.DataFrame()
for i in pd.date_range(date(2020,1,1), periods=366):
    t=df.loc[np.logical_and(df['PurchaseDate']<=i,
                              i<df['RepurchaseDate'])][['Term','CashAmount']].groupby(['Term']).sum().squeeze().rename(i)
    d1=pd.concat([d1,pd.DataFrame(t).T],axis=0)
#d1.head()

# %%
fig = go.Figure()
for i in d1.columns:
    fig.add_trace(go.Scatter(
        x=d1.index, y=d1[i],
        mode='lines',
        line=dict(width=0.5),
        name=i,
        stackgroup='one',
        text=d1.columns,
        customdata=d1.columns
    ))
fig.add_trace(go.Scatter(x=d1.index,y=d1.sum(axis=1),name='Total',line=dict(color='slategray',dash='dot')))
fig.update_traces(hovertemplate='<b>%{y}</b>')
fig.update_layout(title='Repo Market Outstanding Volume',
                  xaxis_title='Date',
                  yaxis_title='Value in CHF',
                  hovermode="x",
                  template='plotly_white')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4299844f-e045-493d-9d65-7f42313bd165" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4299844f-e045-493d-9d65-7f42313bd165")) {                    Plotly.newPlot(                        "4299844f-e045-493d-9d65-7f42313bd165",                        [{"customdata":["1M","1W","3M","6M","ON"],"line":{"width":0.5},"mode":"lines","name":"1M","stackgroup":"one","text":["1M","1W","3M","6M","ON"],"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29 ...

# %%
summ=d1.copy().apply(lambda x: x/x.sum(), axis=1).mean()
summ
# Out:
# Term
# 1M    0.128761
# 1W    0.124469
# 3M    0.098483
# 6M    0.053108
# ON    0.601755
# dtype: float64

# %% [markdown]
# # Question 2

# %%
selection_Q2=['ON','1W','1M']



d2=pd.DataFrame()
for i in pd.date_range(date(2020,1,1), periods=366):
    t=df.loc[np.logical_and(df['PurchaseDate']<=i,
                              i<df['RepurchaseDate'])][['Term','CashAmount','Rate']].groupby(['Term']).apply(
                                  lambda x: np.dot(x['CashAmount']/x['CashAmount'].sum(), x['Rate']).sum() ).squeeze().rename(i)

    #print(t)
    d2=pd.concat([d2,pd.DataFrame(t).T],axis=0)
d2=d2[selection_Q2]

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=d2.index,y=d2['ON'],name='ON',line=dict(color='teal')))
fig.add_trace(go.Scatter(x=d2.index,y=d2['1W'],name='1W',line=dict(color='darkturquoise')))
fig.add_trace(go.Scatter(x=d2.index,y=d2['1M'],name='1M',line=dict(color='darkseagreen')))
fig.update_traces(hovertemplate='<b>%{y}</b>')
fig.update_layout(title='Volume Weighted Avg. Interest Rate (p.a.) on Repos (ON,1W,1M)',
                  xaxis_title='Date',
                  yaxis_title='Rate <b>p.a. (%)</b>',
                  hovermode="x",
                  template='plotly_white')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6d398973-039c-4043-a992-6b375b18b716" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d398973-039c-4043-a992-6b375b18b716")) {                    Plotly.newPlot(                        "6d398973-039c-4043-a992-6b375b18b716",                        [{"line":{"color":"teal"},"name":"ON","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020- ...

# %% [markdown]
# # Question 3

# %%
d3=pd.DataFrame()
def q3(s):
    return s.quantile(0.75)
def q1(s):
  return s.quantile(0.25)

def standardize(x):
  return (x-x.mean())/x.std()
functions={'Rate':['std', q1, q3]}

for i in pd.date_range(date(2020,1,1), periods=366):
    t=df[df['Term']=='ON'].loc[np.logical_and(df['PurchaseDate']<=i,
                              i<df['RepurchaseDate'])][['Term','Rate']].groupby(['Term']).agg(functions).T.reset_index(
                                  level=[0]).drop(columns='level_0').rename(columns={'ON':i}).T
    d3=pd.concat([d3,pd.DataFrame(t)],axis=0)
#d3

# %%
fig1 = make_subplots(specs=[[{"secondary_y": True}]])

fig1_p2=go.Figure(go.Scatter(x=d2['ON'].index,y=d2['ON'].values,mode='lines',name='idIR',line_color='slategray',yaxis="y2",opacity=0.4))
fig1_p2.add_traces(go.Scatter(x=d3['q3'].index,y=d3['q3'].values,fill=None,line=dict(width=0),name='75%',
                              yaxis="y2",line_color='slategray',opacity=0.15))
fig1_p2.add_traces(go.Scatter(x=d3['q1'].index,y=d3['q1'].values,fill='tonexty',fillcolor='rgba(112, 128, 144, 0.1)',
                              line=dict(width=0),name='25%',yaxis="y2",line_color='slategray',opacity=0.15))

fig1_p1=px.line(d3['std'], render_mode="webgl",).update_traces(line_color='teal')

fig1.add_traces(fig1_p1.data + fig1_p2.data).update_layout(showlegend=True,
                       template='plotly_white')
fig1.update_traces(hovertemplate='%{y:.2f}')
fig1.layout.yaxis.title="Volatility (Intraday)<b>(%)</b>"
fig1.layout.yaxis.color="teal"
fig1.layout.yaxis2.title="Mean Interest Rate (Intraday) <b>p.a.(%)</b>"
fig1.layout.yaxis2.color = 'darkgray'
fig1.update_layout(hovermode="x unified",template='plotly_white',
                  hoverlabel=dict(bgcolor='rgba(255,255,255,0.1)',font=dict(color='black')))
fig1.show()
#Collect Hoverdata and plot of returns on that day with median + mean to show how the IQR helps understanding skewness of the interest rate distribution
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e5f7d4d5-06c5-4945-b198-3a8380154705" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5f7d4d5-06c5-4945-b198-3a8380154705")) {                    Plotly.newPlot(                        "e5f7d4d5-06c5-4945-b198-3a8380154705",                        [{"hovertemplate":"%{y:.2f}","legendgroup":"std","line":{"color":"teal","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"std","showlegend":true,"x":["2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-26T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T0 ...

# %% [markdown]
# # Question 4

# %%
#Select all end & beginning of the month and check for significant mean difference with respect to the rest of the month with non-paired sample test
#Two scenarios envisaged:
#1. For given overnight rates, leverage considerations disincentivize banks to borrow and, hence, the volume of outstanding repos at month-end drops
#2. The SNB anticipates leverage considerations of banks at month end and, hence, lowers rates to prevent excessive fluctuations in volume of
#outstanding transaction
d4=pd.DataFrame()
for i in pd.date_range(date(2020,1,1), periods=366):
  t1=df.loc[np.logical_and(df['PurchaseDate']<=i,
                              i<df['RepurchaseDate'])][['Term','CashAmount']].groupby(['Term']).skew().squeeze().rename(i)
  t2=df.loc[np.logical_and(df['PurchaseDate']<=i,
                              i<df['RepurchaseDate'])][['Term','Rate']].groupby(['Term']).skew().squeeze().rename(i)
  if 'ON' in t1.index or 'ON' in t2.index:
    temp=pd.concat([t1,t2],axis=1).T['ON'].rename(i).reset_index(drop=True).set_axis(['ON_Volume_skew','ON_Rate_skew'])
    d4=pd.concat([d4,pd.DataFrame(temp).T],axis=0)

d4=d4.join(pd.concat([d1['ON'].rename('ON_Total_Volume'),d2['ON'].rename('ON_Average_Rate')],axis=1),how='left')
for i in d4.index:
  d4.loc[i,'ON_N_repos']=df[df['Term']=='ON'].loc[np.logical_and(df['PurchaseDate']<=i,
                              i<df['RepurchaseDate'])][['Term','CashAmount']].shape[0]


Month_Ranges=list(zip( [np.min(d4.index[d4.index.month==m]) for m in np.unique(d4.index.month)],
 [np.max(d4.index[d4.index.month==m]) for m in np.unique(d4.index.month)] ))
d4['Month_End_Dummy']=[*pd.Series([*d4.index]).apply(lambda x: 1 if x in [item[1] for item in Month_Ranges] else 0)]

for lag in range(1,7):
  Range_for_Ones=list( zip(d4['Month_End_Dummy'][d4['Month_End_Dummy']==1].index-timedelta(days=lag),d4.index[d4['Month_End_Dummy']==1]) )
  for i in range(len(Range_for_Ones)):
    selection=d4.index[np.logical_and(d4.index>=Range_for_Ones[i][0],
                                     d4.index<=Range_for_Ones[i][1])]
    d4.loc[selection,'Month_End_Dummy'+str(lag)]=1

#d4[['Dummy' in s for s in d4.columns]]=d4[['Dummy' in s for s in d4.columns]].fillna(0)
d4[d4.columns[['Dummy' in s for s in d4.columns]]]=d4[d4.columns[['Dummy' in s for s in d4.columns]]].fillna(0)

# %%
fig=go.Figure(data=[go.Scatter(x=d4[d4['Month_End_Dummy']!=1]['ON_Total_Volume']/d4[d4['Month_End_Dummy']!=1]['ON_N_repos'],y=d4[d4['Month_End_Dummy']!=1]['ON_Average_Rate'],
                                    mode = 'markers',
                                    marker_color=d4[d4['Month_End_Dummy']!=1]['Month_End_Dummy'].replace({1:'indianred',0:'teal'}),
                                    text=[i.date() for i in d4[d4['Month_End_Dummy']!=1].index],hoverinfo = 'text'

                                    )])
fig.add_trace(go.Scatter(x=d4[d4['Month_End_Dummy']==1]['ON_Total_Volume']/d4[d4['Month_End_Dummy']==1]['ON_N_repos'],y=d4[d4['Month_End_Dummy']==1]['ON_Average_Rate'],
                                    mode = 'markers',
                                    marker_color=d4[d4['Month_End_Dummy']==1]['Month_End_Dummy'].replace({1:'indianred',0:'teal'}),
                                    text=[i.date() for i in d4[d4['Month_End_Dummy']==1].index],hoverinfo = 'text'
                                    ))
fig.update_layout(template='plotly_white',xaxis_title='Outstanding Amount',yaxis_title='Rate <b>p.a. (%)</b>')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f9f12879-96ff-4199-9252-db0609fc3ef2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9f12879-96ff-4199-9252-db0609fc3ef2")) {                    Plotly.newPlot(                        "f9f12879-96ff-4199-9252-db0609fc3ef2",                        [{"hoverinfo":"text","marker":{"color":["teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal"]},"mode":"markers","text":["2020-01-04","2020-01-05","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-10","2020-01-11","2020-01-12","2020-01-13","2020-01-14","2020-01-15","2020-01-16","2020-01-17","2020-01-18","2020-01-19","2020-01-20","2020-01-21","2020-01-22","2020-01-23","2020-01-24","2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02-17","2020-02-18","2020-02-19","2020-02-20","2020-02-21","2020-02-22","2020-02-23","2020-02-24","2020-02-25","2020-02-26","2020-02-27","2020-02-28","2020-03-01","2020-03-02","2020-03-03","2020-03-04","2020-03-05","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-11","2020-03-12","2020-03-13","2020-03-14","2020-03-15","2020-03-1 ...

# %% [markdown]
# **Total Volume as Outcome Variable** - Main Result: Only on reporting date Month_End_Dummy has negative coefficient, otherwise always positive. This suggests something, yet one sees **no significant estimated coefficient**

# %%
d4['ON_Total_Volume_std']=standardize(d4['ON_Total_Volume'])
d4['ON_Avg_Volume_std']=standardize(d4['ON_Total_Volume_std']/d4['ON_N_repos'])
d4['ON_Average_Rate_std']=standardize(d4['ON_Average_Rate'])
#

# %%
summaries={}
summaries['0']=sm.OLS(d4['ON_Total_Volume'],
                      sm.add_constant(d4[['Month_End_Dummy','ON_Average_Rate']])).fit(cov_type='HC1').summary()
for i in range(1,7):
  summaries[i]=sm.OLS(d4['ON_Total_Volume'],
                      sm.add_constant(d4[['Month_End_Dummy'+str(i),'ON_Average_Rate']])).fit(cov_type='HC1').summary()

summaries
# Out:
# {'0': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.573
#  Model:                            OLS   Adj. R-squared:                  0.571
#  Method:                 Least Squares   F-statistic:                     463.1
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):          3.83e-100
#  Time:                        20:47:31   Log-Likelihood:                -8998.2
#  No. Observations:                 362   AIC:                         1.800e+04
#  Df Residuals:                     359   BIC:                         1.801e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ===================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
#  -----------------------------------------------------------------------------------
#  const           -2.881e+09   1.97e+09     -1.466      0.143   -6.73e+09    9.71e+08
#  Month_End_Dummy -8.764e+08   3.72e+09     -0.235      0.814   -8.18e+09    6.42e+09
#  ON_Average_Rate  4.407e+10   1.47e+09     29.884      0.000    4.12e+10     4.7e+10
#  ==============================================================================
#  Omnibus:                      155.736   Durbin-Watson:                   0.037
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              692.527
#  Skew:                          -1.841   Prob(JB):                    4.17e-151
#  Kurtosis:                       8.688   Cond. No.                         11.1
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  1: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.573
#  Model:                            OLS   Adj. R-squared:                  0.571
#  Method:                 Least Squares   F-statistic:                     471.0
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):          4.21e-101
#  Time:                        20:47:31   Log-Likelihood:                -8998.2
#  No. Observations:                 362   AIC:                         1.800e+04
#  Df Residuals:                     359   BIC:                         1.801e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const            -2.989e+09   1.93e+09     -1.551      0.121   -6.77e+09    7.89e+08
#  Month_End_Dummy1  5.455e+08   2.76e+09      0.198      0.843   -4.86e+09    5.95e+09
#  ON_Average_Rate    4.41e+10   1.46e+09     30.258      0.000    4.12e+10     4.7e+10
#  ==============================================================================
#  Omnibus:                      155.409   Durbin-Watson:                   0.038
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              688.250
#  Skew:                          -1.838   Prob(JB):                    3.53e-150
#  Kurtosis:                       8.667   Cond. No.                         9.83
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  2: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.574
#  Model:                            OLS   Adj. R-squared:                  0.571
#  Method:                 Least Squares   F-statistic:                     486.0
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):          7.15e-103
#  Time:                        20:47:31   Log-Likelihood:                -8998.0
#  No. Observations:                 362   AIC:                         1.800e+04
#  Df Residuals:                     359   BIC:                         1.801e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const            -3.176e+09   1.89e+09     -1.678      0.093   -6.89e+09    5.34e+08
#  Month_End_Dummy2  1.626e+09   2.28e+09      0.713      0.476   -2.84e+09    6.09e+09
#  ON_Average_Rate   4.414e+10   1.44e+09     30.625      0.000    4.13e+10     4.7e+10
#  ==============================================================================
#  Omnibus:                      155.006   Durbin-Watson:                   0.039
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              682.771
#  Skew:                          -1.835   Prob(JB):                    5.47e-149
#  Kurtosis:                       8.639   Cond. No.                         9.83
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  3: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.575
#  Model:                            OLS   Adj. R-squared:                  0.572
#  Method:                 Least Squares   F-statistic:                     505.7
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):          3.72e-105
#  Time:                        20:47:31   Log-Likelihood:                -8997.6
#  No. Observations:                 362   AIC:                         1.800e+04
#  Df Residuals:                     359   BIC:                         1.801e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const            -3.312e+09   1.86e+09     -1.779      0.075   -6.96e+09    3.36e+08
#  Month_End_Dummy3  2.537e+09   2.07e+09      1.226      0.220   -1.52e+09    6.59e+09
#  ON_Average_Rate   4.412e+10   1.44e+09     30.722      0.000    4.13e+10    4.69e+10
#  ==============================================================================
#  Omnibus:                      154.560   Durbin-Watson:                   0.039
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              676.090
#  Skew:                          -1.832   Prob(JB):                    1.55e-147
#  Kurtosis:                       8.603   Cond. No.                         9.80
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  4: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.576
#  Model:                            OLS   Adj. R-squared:                  0.573
#  Method:                 Least Squares   F-statistic:                     516.5
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):          2.24e-106
#  Time:                        20:47:31   Log-Likelihood:                -8997.2
#  No. Observations:                 362   AIC:                         1.800e+04
#  Df Residuals:                     359   BIC:                         1.801e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             -3.52e+09   1.84e+09     -1.909      0.056   -7.14e+09    9.49e+07
#  Month_End_Dummy4  3.033e+09    1.9e+09      1.600      0.110   -6.83e+08    6.75e+09
#  ON_Average_Rate   4.414e+10   1.43e+09     30.892      0.000    4.13e+10    4.69e+10
#  ==============================================================================
#  Omnibus:                      154.330   Durbin-Watson:                   0.040
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              671.647
#  Skew:                          -1.831   Prob(JB):                    1.42e-146
#  Kurtosis:                       8.578   Cond. No.                         9.83
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  5: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.577
#  Model:                            OLS   Adj. R-squared:                  0.574
#  Method:                 Least Squares   F-statistic:                     526.0
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):          2.00e-107
#  Time:                        20:47:31   Log-Likelihood:                -8996.7
#  No. Observations:                 362   AIC:                         1.800e+04
#  Df Residuals:                     359   BIC:                         1.801e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const            -3.735e+09   1.83e+09     -2.036      0.042   -7.33e+09    -1.4e+08
#  Month_End_Dummy5  3.378e+09   1.77e+09      1.905      0.057   -9.81e+07    6.85e+09
#  ON_Average_Rate   4.417e+10   1.42e+09     31.009      0.000    4.14e+10     4.7e+10
#  ==============================================================================
#  Omnibus:                      154.079   Durbin-Watson:                   0.041
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              667.045
#  Skew:                          -1.830   Prob(JB):                    1.42e-145
#  Kurtosis:                       8.552   Cond. No.                         9.86
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  6: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.578
#  Model:                            OLS   Adj. R-squared:                  0.575
#  Method:                 Least Squares   F-statistic:                     534.5
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):          2.31e-108
#  Time:                        20:47:31   Log-Likelihood:                -8996.3
#  No. Observations:                 362   AIC:                         1.800e+04
#  Df Residuals:                     359   BIC:                         1.801e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const            -3.945e+09   1.83e+09     -2.158      0.031   -7.53e+09   -3.63e+08
#  Month_End_Dummy6  3.617e+09   1.69e+09      2.145      0.032    3.13e+08    6.92e+09
#  ON_Average_Rate    4.42e+10   1.42e+09     31.089      0.000    4.14e+10     4.7e+10
#  ==============================================================================
#  Omnibus:                      153.760   Durbin-Watson:                   0.042
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              661.685
#  Skew:                          -1.829   Prob(JB):                    2.07e-144
#  Kurtosis:                       8.522   Cond. No.                         9.89
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """}

# %%
A=sm.OLS(d4['ON_Total_Volume'],
                      sm.add_constant(d4[['Month_End_Dummy','ON_Average_Rate']])).fit(cov_type='HC1')
pd.concat([A.params,A.pvalues],axis=1).rename(columns={0:'Coefficient',1:'PValue'})
# Out:
#                   Coefficient         PValue
# const           -2.881365e+09   1.426569e-01
# Month_End_Dummy -8.764006e+08   8.139475e-01
# ON_Average_Rate  4.407408e+10  3.175731e-196

# %%
summaries={}
summaries['0']=sm.OLS(d4['ON_Total_Volume']/d4['ON_N_repos'],
                      sm.add_constant(d4[['Month_End_Dummy','ON_Average_Rate']])).fit(cov_type='HC1').summary()
for i in range(1,7):
  summaries[i]=sm.OLS(d4['ON_Total_Volume']/d4['ON_N_repos'],
                      sm.add_constant(d4[['Month_End_Dummy'+str(i),'ON_Average_Rate']])).fit(cov_type='HC1').summary()

summaries
# Out:
# {'0': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.438
#  Model:                            OLS   Adj. R-squared:                  0.435
#  Method:                 Least Squares   F-statistic:                     40.15
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):           1.84e-16
#  Time:                        20:47:31   Log-Likelihood:                -6436.7
#  No. Observations:                 362   AIC:                         1.288e+04
#  Df Residuals:                     359   BIC:                         1.289e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ===================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
#  -----------------------------------------------------------------------------------
#  const            2.132e+08   9.33e+06     22.853      0.000    1.95e+08    2.32e+08
#  Month_End_Dummy -1.509e+07   1.21e+07     -1.252      0.211   -3.87e+07    8.53e+06
#  ON_Average_Rate -2.779e+07   5.52e+06     -5.036      0.000   -3.86e+07    -1.7e+07
#  ==============================================================================
#  Omnibus:                      303.907   Durbin-Watson:                   0.600
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24364.823
#  Skew:                          -2.886   Prob(JB):                         0.00
#  Kurtosis:                      42.775   Cond. No.                         11.1
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  1: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.429
#  Model:                            OLS   Adj. R-squared:                  0.426
#  Method:                 Least Squares   F-statistic:                     39.17
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):           4.11e-16
#  Time:                        20:47:31   Log-Likelihood:                -6439.5
#  No. Observations:                 362   AIC:                         1.289e+04
#  Df Residuals:                     359   BIC:                         1.290e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             2.133e+08   9.67e+06     22.049      0.000    1.94e+08    2.32e+08
#  Month_End_Dummy1 -8.742e+06   6.22e+06     -1.405      0.160   -2.09e+07    3.46e+06
#  ON_Average_Rate  -2.775e+07   5.72e+06     -4.851      0.000    -3.9e+07   -1.65e+07
#  ==============================================================================
#  Omnibus:                      334.787   Durbin-Watson:                   0.604
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):            32464.960
#  Skew:                          -3.335   Prob(JB):                         0.00
#  Kurtosis:                      48.912   Cond. No.                         9.83
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  2: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.424
#  Model:                            OLS   Adj. R-squared:                  0.421
#  Method:                 Least Squares   F-statistic:                     34.99
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):           1.31e-14
#  Time:                        20:47:31   Log-Likelihood:                -6441.2
#  No. Observations:                 362   AIC:                         1.289e+04
#  Df Residuals:                     359   BIC:                         1.290e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             2.132e+08   9.85e+06     21.645      0.000    1.94e+08    2.33e+08
#  Month_End_Dummy2 -5.936e+06   4.22e+06     -1.405      0.160   -1.42e+07    2.34e+06
#  ON_Average_Rate  -2.773e+07   5.82e+06     -4.764      0.000   -3.91e+07   -1.63e+07
#  ==============================================================================
#  Omnibus:                      347.055   Durbin-Watson:                   0.582
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36274.918
#  Skew:                          -3.523   Prob(JB):                         0.00
#  Kurtosis:                      51.532   Cond. No.                         9.83
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  3: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.421
#  Model:                            OLS   Adj. R-squared:                  0.418
#  Method:                 Least Squares   F-statistic:                     33.45
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):           4.77e-14
#  Time:                        20:47:31   Log-Likelihood:                -6442.0
#  No. Observations:                 362   AIC:                         1.289e+04
#  Df Residuals:                     359   BIC:                         1.290e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const              2.13e+08      1e+07     21.307      0.000    1.93e+08    2.33e+08
#  Month_End_Dummy3 -4.671e+06   3.42e+06     -1.365      0.172   -1.14e+07    2.04e+06
#  ON_Average_Rate  -2.761e+07   5.92e+06     -4.665      0.000   -3.92e+07    -1.6e+07
#  ==============================================================================
#  Omnibus:                      351.004   Durbin-Watson:                   0.577
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37743.019
#  Skew:                          -3.583   Prob(JB):                         0.00
#  Kurtosis:                      52.507   Cond. No.                         9.80
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  4: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.417
#  Model:                            OLS   Adj. R-squared:                  0.414
#  Method:                 Least Squares   F-statistic:                     29.85
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):           1.02e-12
#  Time:                        20:47:31   Log-Likelihood:                -6443.2
#  No. Observations:                 362   AIC:                         1.289e+04
#  Df Residuals:                     359   BIC:                         1.290e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const              2.13e+08   1.01e+07     21.133      0.000    1.93e+08    2.33e+08
#  Month_End_Dummy4 -3.103e+06   2.85e+06     -1.088      0.276   -8.69e+06    2.49e+06
#  ON_Average_Rate  -2.761e+07   5.97e+06     -4.626      0.000   -3.93e+07   -1.59e+07
#  ==============================================================================
#  Omnibus:                      355.472   Durbin-Watson:                   0.574
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):            39787.992
#  Skew:                          -3.649   Prob(JB):                         0.00
#  Kurtosis:                      53.839   Cond. No.                         9.83
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  5: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.415
#  Model:                            OLS   Adj. R-squared:                  0.412
#  Method:                 Least Squares   F-statistic:                     26.60
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):           1.69e-11
#  Time:                        20:47:31   Log-Likelihood:                -6443.9
#  No. Observations:                 362   AIC:                         1.289e+04
#  Df Residuals:                     359   BIC:                         1.291e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             2.128e+08   1.01e+07     21.031      0.000    1.93e+08    2.33e+08
#  Month_End_Dummy5 -2.029e+06   2.47e+06     -0.822      0.411   -6.87e+06    2.81e+06
#  ON_Average_Rate   -2.76e+07      6e+06     -4.602      0.000   -3.94e+07   -1.58e+07
#  ==============================================================================
#  Omnibus:                      358.679   Durbin-Watson:                   0.569
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41202.321
#  Skew:                          -3.698   Prob(JB):                         0.00
#  Kurtosis:                      54.739   Cond. No.                         9.86
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  6: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.414
#  Model:                            OLS   Adj. R-squared:                  0.411
#  Method:                 Least Squares   F-statistic:                     23.90
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):           1.80e-10
#  Time:                        20:47:31   Log-Likelihood:                -6444.4
#  No. Observations:                 362   AIC:                         1.289e+04
#  Df Residuals:                     359   BIC:                         1.291e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             2.127e+08   1.01e+07     20.969      0.000    1.93e+08    2.33e+08
#  Month_End_Dummy6 -1.206e+06   2.19e+06     -0.551      0.582    -5.5e+06    3.09e+06
#  ON_Average_Rate  -2.759e+07   6.02e+06     -4.586      0.000   -3.94e+07   -1.58e+07
#  ==============================================================================
#  Omnibus:                      361.320   Durbin-Watson:                   0.567
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):            42286.879
#  Skew:                          -3.739   Prob(JB):                         0.00
#  Kurtosis:                      55.418   Cond. No.                         9.89
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """}

# %%
d4_copia=d4.copy()#[d4.copy().index.month!=12]
d4_copia['ON_Avg_Outstanding_Volume']=d4['ON_Total_Volume']/d4['ON_N_repos']

quant_formula = 'ON_Total_Volume ~ Month_End_Dummy + ON_Average_Rate'
quant_mod = smf.quantreg(quant_formula, d4_copia)
quantiles = [0.01,0.1, 0.25, 0.5, 0.75, 0.90,0.99]  # Quantiles of interest

quant_results = []
for quantile in quantiles:
    quant_result = quant_mod.fit(q=quantile, max_iter=10000)
    quant_results.append(quant_result)

for quantile, quant_result in zip(quantiles, quant_results):
    print(f"Quantile: {quantile}")
    print(quant_result.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning:
#
# Maximum number of iterations (10000) reached.
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning:
#
# Maximum number of iterations (10000) reached.
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning:
#
# Maximum number of iterations (10000) reached.
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning:
#
# Maximum number of iterations (10000) reached.
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning:
#
# Maximum number of iterations (10000) reached.
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning:
#
# Maximum number of iterations (10000) reached.
# Quantile: 0.01
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:        ON_Total_Volume   Pseudo R-squared:              0.08264
# Model:                       QuantReg   Bandwidth:                   3.298e+10
# Method:                 Least Squares   Sparsity:                    5.083e+11
# Date:                Mon, 11 Mar 2024   No. Observations:                  362
# Time:                        20:47:41   Df Residuals:                      359
#                                         Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        2.581e+09    4.9e+10      0.053      0.958   -9.38e+10     9.9e+10
# Month_End_Dummy  8.126e+08    4.1e+10      0.020      0.984   -7.98e+10    8.14e+10
# ON_Average_Rate   5.58e+09   2.86e+10      0.195      0.845   -5.06e+10    6.18e+10
# ===================================================================================
# Quantile: 0.1
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:        ON_Total_Volume   Pseudo R-squared:               0.4837
# Model:                       QuantReg   Bandwidth:                   1.077e+10
# Method:                 Least Squares   Sparsity:                    6.096e+10
# Date:                Mon, 11 Mar 2024   No. Observations:                  362
# Time:                        20:47:41   Df Residuals:                      359
#                                         Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept       -2.132e+09   3.81e+09     -0.559      0.576   -9.63e+09    5.37e+09
# Month_End_Dummy -7.459e+08   6.74e+09     -0.111      0.912    -1.4e+10    1.25e+10
# ON_Average_Rate  3.221e+10   2.29e+09     14.070      0.000    2.77e+10    3.67e+10
# ===================================================================================
# Quantile: 0.25
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:        ON_Total_Volume   Pseudo R-squared:               0.3600
# Model:                       QuantReg   Bandwidth:                   9.888e+09
# Method:                 Least Squares   Sparsity:                    5.722e+10
# Date:                Mon, 11 Mar 2024   No. Observations:                  362
# Time:                        20:47:41   Df Residuals:                      359
#                                         Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept       -3.502e+09   5.67e+09     -0.618      0.537   -1.47e+10    7.65e+09
# Month_End_Dummy    -0.0002   7.29e+09  -2.66e-14      1.000   -1.43e+10    1.43e+10
# ON_Average_Rate  3.837e+10   3.31e+09     11.604      0.000    3.19e+10    4.49e+10
# ===================================================================================
# Quantile: 0.5
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:        ON_Total_Volume   Pseudo R-squared:               0.3668
# Model:                       QuantReg   Bandwidth:                   1.033e+10
# Method:                 Least Squares   Sparsity:                    2.785e+10
# Date:                Mon, 11 Mar 2024   No. Observations:                  362
# Time:                        20:47:41   Df Residuals:                      359
#                                         Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept       -5.055e+09   3.15e+09     -1.605      0.109   -1.13e+10    1.14e+09
# Month_End_Dummy  -2.37e+09   4.09e+09     -0.579      0.563   -1.04e+10    5.67e+09
# ON_Average_Rate  4.861e+10   1.84e+09     26.356      0.000     4.5e+10    5.22e+10
# ===================================================================================
# Quantile: 0.75
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:        ON_Total_Volume   Pseudo R-squared:               0.3526
# Model:                       QuantReg   Bandwidth:                   9.118e+09
# Method:                 Least Squares   Sparsity:                    2.390e+10
# Date:                Mon, 11 Mar 2024   No. Observations:                  362
# Time:                        20:47:41   Df Residuals:                      359
#                                         Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept       -5.307e+09   2.86e+09     -1.857      0.064   -1.09e+10    3.14e+08
# Month_End_Dummy -3.848e+09   3.03e+09     -1.271      0.205    -9.8e+09    2.11e+09
# ON_Average_Rate  5.163e+10   1.68e+09     30.776      0.000    4.83e+10    5.49e+10
# ===================================================================================
# Quantile: 0.9
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:        ON_Total_Volume   Pseudo R-squared:               0.3364
# Model:                       QuantReg   Bandwidth:                   8.873e+09
# Method:                 Least Squares   Sparsity:                    2.935e+10
# Date:                Mon, 11 Mar 2024   No. Observations:                  362
# Time:                        20:47:41   Df Residuals:                      359
#                                         Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept       -3.309e+09   2.32e+09     -1.428      0.154   -7.87e+09    1.25e+09
# Month_End_Dummy -3.883e+09   2.33e+09     -1.665      0.097   -8.47e+09    7.02e+08
# ON_Average_Rate  5.231e+10    1.4e+09     37.335      0.000    4.96e+10    5.51e+10
# ===================================================================================
# Quantile: 0.99
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:        ON_Total_Volume   Pseudo R-squared:               0.3500
# Model:                       QuantReg   Bandwidth:                   2.437e+10
# Method:                 Least Squares   Sparsity:                    5.611e+10
# Date:                Mon, 11 Mar 2024   No. Observations:                  362
# Time:                        20:47:41   Df Residuals:                      359
#                                         Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept       -2.688e+09   3.93e+09     -0.684      0.494   -1.04e+10    5.04e+09
# Month_End_Dummy  1.845e+10   4.51e+09      4.088      0.000    9.57e+09    2.73e+10
# ON_Average_Rate  5.386e+10   2.33e+09     23.140      0.000    4.93e+10    5.84e+10
# ===================================================================================
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning:
#
# Maximum number of iterations (10000) reached.

# %%
A=pd.DataFrame()
for i in range(len(quantiles)):
  AA=pd.concat([quant_results[i].params, quant_results[i].pvalues],axis=1).rename(columns={0:'Coefficient',
                                                                                          1:'Pvalue'}).loc['Month_End_Dummy',:].rename(quantiles[i])
  A=pd.concat([A,AA],axis=1)
A.T
# Out:
#        Coefficient    Pvalue
# 0.01  8.126404e+08  0.984195
# 0.10 -7.459391e+08  0.911975
# 0.25 -1.937883e-04  1.000000
# 0.50 -2.370145e+09  0.562656
# 0.75 -3.848028e+09  0.204602
# 0.90 -3.883035e+09  0.096702
# 0.99  1.844567e+10  0.000054

# %%
functions={'CashAmount':['median', q1, q3]}
dd=pd.DataFrame()
for i in pd.date_range(date(2020,1,1), periods=366):
    t=df[df['Term']=='ON'].loc[np.logical_and(df['PurchaseDate']<=i,
                              i<df['RepurchaseDate'])][['Term','CashAmount']].groupby(['Term']).agg(functions).T.reset_index(
                                  level=[0]).drop(columns='level_0').rename(columns={'ON':i}).T
    dd=pd.concat([dd,t],axis=0)
dd=pd.concat([d4,dd],axis=1)

fig1=go.Figure()
for month in np.arange(1,13):
  if month!=12:
    switch='legendonly'
  else:
    switch=True
  t=dd[dd.index.month==month].reset_index().set_index(np.arange(1,len(dd[dd.index.month==month])+1)/dd[dd.index.month==month].shape[0])
  fig1.add_trace(go.Scatter(x=t['ON_Total_Volume'].index,y=t['ON_Total_Volume']/t['ON_N_repos'],name=str(calendar.month_abbr[month]),
                           visible=switch))
  fig1.add_traces(go.Scatter(x=t['q3'].index,y=t['q3'].values,fill=None,line=dict(width=0),name=str(calendar.month_abbr[month])+'75%',
                              line_color='slategray',opacity=0.15,visible=switch))
  fig1.add_traces(go.Scatter(x=t['q1'].index,y=t['q1'].values,fill='tonexty',fillcolor='rgba(112, 128, 144, 0.1)',
                              line=dict(width=0),name=str(calendar.month_abbr[month])+'25%',line_color='slategray',opacity=0.15,visible=switch))
  fig1.add_traces(go.Scatter(x=t['median'].index,y=t['median'].values,name=str(calendar.month_abbr[month])+'50%',visible=switch))
  fig1.update_layout(template='plotly_white')
fig1
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="10a213d6-a0d4-4a97-8f93-46ca1075a967" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10a213d6-a0d4-4a97-8f93-46ca1075a967")) {                    Plotly.newPlot(                        "10a213d6-a0d4-4a97-8f93-46ca1075a967",                        [{"name":"Jan","visible":"legendonly","x":[0.03571428571428571,0.07142857142857142,0.10714285714285714,0.14285714285714285,0.17857142857142858,0.21428571428571427,0.25,0.2857142857142857,0.32142857142857145,0.35714285714285715,0.39285714285714285,0.42857142857142855,0.4642857142857143,0.5,0.5357142857142857,0.5714285714285714,0.6071428571428571,0.6428571428571429,0.6785714285714286,0.7142857142857143,0.75,0.7857142857142857,0.8214285714285714,0.8571428571428571,0.8928571428571429,0.9285714285714286,0.9642857142857143,1.0],"y":[178217391.3043478,178217391.3043478,164214285.7142857,181887218.0451128,181887218.0451128,182111111.1111111,182666666.66666666,182666666.66666666,183824817.51824817,176753894.08099687,180087087.0870871,181204268.29268292,180224683.5443038,178410094.637224,178410094.637224,178410094.637224,179791798.10725552,177391975.30864197,178760869.5652174,182065217.39130434,178088685.01529053,178088685.01529053,178088685.01529053,182380952.3809524,180128125.0,179885245.90163934,177419558.35962147,164462878.54611987],"type":"scatter"},{"line":{"color":"slategray","width":0},"name":"Jan75%","opacity":0.15,"visible":"legendonly","x":[0.03571428571428571,0.07142857142857142,0.10714285714285714,0.14285714285714285,0.17857142857142858,0.21428571428571427,0.25,0.2857142857142857,0.32142857142857145,0.35714285714285715,0.39285714285714285,0.42857142857142855,0.4642857142857143,0.5,0.5357142857142857,0.5714285714285714,0.6071428571428571,0.6428571428571429,0.6785714285714286,0.7142857142857143,0.75,0.7857142857142857,0.8214285714285714,0.8571428571428571,0.8928571428571429,0.9285714285714286,0.9642857142857143,1.0],"y":[200000000.0,200000000.0,192500000.0,205000000.0,205000000.0,210000000.0,210000000.0,210000000.0,210000000.0,190000000.0,210000000.0,206250000.0,210000000.0,205000000.0,205000000.0,205000000.0,210000000.0,206250000.0,203750000.0,210000000.0,202500000.0,202500000.0,202500000.0,210000000.0,201250000.0,205000000.0,200000000.0,180000000.0],"type":"scatter"},{"fill":"tonexty","fillcolor":"rgba(112, 128, 144, 0.1)","line":{"color":"slategray","width":0},"name":"Jan25%","opacity":0.15,"visible":"legendonly","x":[0.03571428571428571,0.07142857142857142,0.10714285714285714,0.14285714285714285,0.17857142857142858,0.21428571428571427,0.25,0.2857142857142857,0.32142857142857145,0.35714285714285715,0.39285714285714285,0.42857142857142855,0.4642857142857143,0.5,0.5357142857142857,0.5714285714285714,0.6071428571428571,0.6428571428571429,0.6785714285714286,0.7142857142857143,0.75,0.7857142857142857,0.8214285714285714,0.8571428571428571,0.8928571428571429,0.9285714285714286,0.9642857142857143,1.0],"y":[100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,100000000.0,82000000.0],"type":"scatter"},{"name":"Jan50%","visible":"legendonly","x":[0.03571428571428571,0.07142857142857142,0.10714285714285714,0.14285714285714285,0.17857142857142858,0.21428571428571427,0.25,0.2857142857142857,0.32142857142857145,0.35714285714285715,0.39285714285714285,0.42857142857142855,0.4642857142857143,0.5,0.5357142857142857,0.5714285714285714,0.6071428571428571,0.6428571428571429,0.6785714285714286,0.7142857142857143,0.75,0.7857142857142857,0.8 ...

# %%
figu=make_subplots(rows=1,cols=2)
figu.add_traces(fig.data,1,1)
figu.add_traces(fig1.data,1,2)
figu.update_layout(template='plotly_white')
figu.update_xaxes(title_text="Oustanding Volune", row=1, col=1)
figu.update_yaxes(title_text="Interest Rate p.a.(%)", row=1, col=1)
figu.update_yaxes(title_text="Outstanding Volume", row=1, col=2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="15aa70b0-3046-4374-b5f0-9ffba76f322e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15aa70b0-3046-4374-b5f0-9ffba76f322e")) {                    Plotly.newPlot(                        "15aa70b0-3046-4374-b5f0-9ffba76f322e",                        [{"hoverinfo":"text","marker":{"color":["teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal","teal"]},"mode":"markers","text":["2020-01-04","2020-01-05","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-10","2020-01-11","2020-01-12","2020-01-13","2020-01-14","2020-01-15","2020-01-16","2020-01-17","2020-01-18","2020-01-19","2020-01-20","2020-01-21","2020-01-22","2020-01-23","2020-01-24","2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02-17","2020-02-18","2020-02-19","2020-02-20","2020-02-21","2020-02-22","2020-02-23","2020-02-24","2020-02-25","2020-02-26","2020-02-27","2020-02-28","2020-03-01","2020-03-02","2020-03-03","2020-03-04","2020-03-05","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-11","2020-03-12","2020-03-13","2020-03-14","2020-03-15","2020-03-1 ...

# %%
d4_DecOut=d4[d4.index.month!=12]
summaries={}
summaries['0']=sm.OLS(d4_DecOut['ON_Total_Volume'],
                      sm.add_constant(d4_DecOut[['Month_End_Dummy','ON_Average_Rate']])).fit(cov_type='HC1').summary()
for i in range(1,7):
  summaries[i]=sm.OLS(d4_DecOut['ON_Total_Volume'],
                      sm.add_constant(d4_DecOut[['Month_End_Dummy'+str(i),'ON_Average_Rate']])).fit(cov_type='HC1').summary()

summaries
# Out:
# {'0': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.025
#  Model:                            OLS   Adj. R-squared:                  0.019
#  Method:                 Least Squares   F-statistic:                     1.565
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.211
#  Time:                        20:51:05   Log-Likelihood:                -8257.7
#  No. Observations:                 332   AIC:                         1.652e+04
#  Df Residuals:                     329   BIC:                         1.653e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ===================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
#  -----------------------------------------------------------------------------------
#  const            3.412e+10    2.5e+10      1.363      0.173   -1.49e+10    8.32e+10
#  Month_End_Dummy -3.233e+09   3.93e+09     -0.822      0.411   -1.09e+10    4.47e+09
#  ON_Average_Rate   2.34e+10   1.44e+10      1.621      0.105    -4.9e+09    5.17e+10
#  ==============================================================================
#  Omnibus:                      111.205   Durbin-Watson:                   0.030
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              330.079
#  Skew:                          -1.532   Prob(JB):                     2.11e-72
#  Kurtosis:                       6.805   Cond. No.                         40.8
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  1: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.024
#  Model:                            OLS   Adj. R-squared:                  0.018
#  Method:                 Least Squares   F-statistic:                     1.337
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.264
#  Time:                        20:51:05   Log-Likelihood:                -8257.9
#  No. Observations:                 332   AIC:                         1.652e+04
#  Df Residuals:                     329   BIC:                         1.653e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             3.394e+10    2.5e+10      1.359      0.174    -1.5e+10    8.29e+10
#  Month_End_Dummy1 -9.504e+08   3.05e+09     -0.312      0.755   -6.92e+09    5.02e+09
#  ON_Average_Rate   2.348e+10   1.44e+10      1.629      0.103   -4.77e+09    5.17e+10
#  ==============================================================================
#  Omnibus:                      110.732   Durbin-Watson:                   0.031
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              327.294
#  Skew:                          -1.527   Prob(JB):                     8.49e-72
#  Kurtosis:                       6.787   Cond. No.                         40.9
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  2: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.024
#  Model:                            OLS   Adj. R-squared:                  0.018
#  Method:                 Least Squares   F-statistic:                     1.409
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.246
#  Time:                        20:51:05   Log-Likelihood:                -8258.0
#  No. Observations:                 332   AIC:                         1.652e+04
#  Df Residuals:                     329   BIC:                         1.653e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             3.362e+10   2.49e+10      1.349      0.177   -1.52e+10    8.24e+10
#  Month_End_Dummy2  3.826e+08   2.52e+09      0.152      0.879   -4.56e+09    5.32e+09
#  ON_Average_Rate   2.361e+10   1.44e+10      1.641      0.101   -4.58e+09    5.18e+10
#  ==============================================================================
#  Omnibus:                      110.438   Durbin-Watson:                   0.032
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              324.813
#  Skew:                          -1.524   Prob(JB):                     2.94e-71
#  Kurtosis:                       6.766   Cond. No.                         40.9
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  3: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.024
#  Model:                            OLS   Adj. R-squared:                  0.019
#  Method:                 Least Squares   F-statistic:                     1.772
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.172
#  Time:                        20:51:05   Log-Likelihood:                -8257.8
#  No. Observations:                 332   AIC:                         1.652e+04
#  Df Residuals:                     329   BIC:                         1.653e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             3.311e+10   2.48e+10      1.333      0.183   -1.56e+10    8.18e+10
#  Month_End_Dummy3  1.439e+09   2.23e+09      0.646      0.518   -2.93e+09     5.8e+09
#  ON_Average_Rate   2.381e+10   1.43e+10      1.660      0.097   -4.31e+09    5.19e+10
#  ==============================================================================
#  Omnibus:                      110.302   Durbin-Watson:                   0.032
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              323.105
#  Skew:                          -1.524   Prob(JB):                     6.90e-71
#  Kurtosis:                       6.750   Cond. No.                         41.0
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  4: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.026
#  Model:                            OLS   Adj. R-squared:                  0.020
#  Method:                 Least Squares   F-statistic:                     2.272
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.105
#  Time:                        20:51:05   Log-Likelihood:                -8257.5
#  No. Observations:                 332   AIC:                         1.652e+04
#  Df Residuals:                     329   BIC:                         1.653e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             3.264e+10   2.48e+10      1.318      0.187   -1.59e+10    8.12e+10
#  Month_End_Dummy4  2.073e+09   2.04e+09      1.017      0.309   -1.92e+09    6.07e+09
#  ON_Average_Rate   2.399e+10   1.43e+10      1.676      0.094   -4.06e+09     5.2e+10
#  ==============================================================================
#  Omnibus:                      110.285   Durbin-Watson:                   0.033
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              322.072
#  Skew:                          -1.526   Prob(JB):                     1.16e-70
#  Kurtosis:                       6.738   Cond. No.                         41.1
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  5: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.028
#  Model:                            OLS   Adj. R-squared:                  0.022
#  Method:                 Least Squares   F-statistic:                     2.838
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):             0.0600
#  Time:                        20:51:05   Log-Likelihood:                -8257.3
#  No. Observations:                 332   AIC:                         1.652e+04
#  Df Residuals:                     329   BIC:                         1.653e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             3.221e+10   2.47e+10      1.305      0.192   -1.62e+10    8.06e+10
#  Month_End_Dummy5  2.511e+09    1.9e+09      1.320      0.187   -1.22e+09    6.24e+09
#  ON_Average_Rate   2.414e+10   1.43e+10      1.691      0.091   -3.84e+09    5.21e+10
#  ==============================================================================
#  Omnibus:                      110.262   Durbin-Watson:                   0.033
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              320.912
#  Skew:                          -1.527   Prob(JB):                     2.06e-70
#  Kurtosis:                       6.724   Cond. No.                         41.1
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  6: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:        ON_Total_Volume   R-squared:                       0.029
#  Model:                            OLS   Adj. R-squared:                  0.023
#  Method:                 Least Squares   F-statistic:                     3.440
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):             0.0332
#  Time:                        20:51:05   Log-Likelihood:                -8257.0
#  No. Observations:                 332   AIC:                         1.652e+04
#  Df Residuals:                     329   BIC:                         1.653e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             3.186e+10   2.46e+10      1.294      0.196   -1.64e+10    8.01e+10
#  Month_End_Dummy6  2.821e+09    1.8e+09      1.564      0.118   -7.14e+08    6.35e+09
#  ON_Average_Rate   2.425e+10   1.42e+10      1.702      0.089   -3.67e+09    5.22e+10
#  ==============================================================================
#  Omnibus:                      110.140   Durbin-Watson:                   0.034
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              319.036
#  Skew:                          -1.528   Prob(JB):                     5.27e-70
#  Kurtosis:                       6.705   Cond. No.                         41.2
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """}

# %% [markdown]
# **No significance gain when looking at linear regressions with outstanding amount as outcome variable**

# %%
summaries={}
summaries['0']=sm.OLS(d4_DecOut['ON_Total_Volume']/d4_DecOut['ON_N_repos'],
                      sm.add_constant(d4_DecOut[['Month_End_Dummy','ON_Average_Rate']])).fit(cov_type='HC1').summary()
for i in range(1,7):
  summaries[i]=sm.OLS(d4_DecOut['ON_Total_Volume']/d4_DecOut['ON_N_repos'],
                      sm.add_constant(d4_DecOut[['Month_End_Dummy'+str(i),'ON_Average_Rate']])).fit(cov_type='HC1').summary()

summaries
# Out:
# {'0': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.011
#  Model:                            OLS   Adj. R-squared:                  0.005
#  Method:                 Least Squares   F-statistic:                     1.721
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.180
#  Time:                        20:51:05   Log-Likelihood:                -5751.5
#  No. Observations:                 332   AIC:                         1.151e+04
#  Df Residuals:                     329   BIC:                         1.152e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ===================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
#  -----------------------------------------------------------------------------------
#  const             1.78e+08   8.55e+06     20.831      0.000    1.61e+08    1.95e+08
#  Month_End_Dummy  -1.49e+06    2.1e+06     -0.708      0.479   -5.61e+06    2.63e+06
#  ON_Average_Rate -8.179e+06   4.96e+06     -1.649      0.099   -1.79e+07    1.54e+06
#  ==============================================================================
#  Omnibus:                        5.584   Durbin-Watson:                   0.088
#  Prob(Omnibus):                  0.061   Jarque-Bera (JB):                5.348
#  Skew:                           0.300   Prob(JB):                       0.0690
#  Kurtosis:                       3.160   Cond. No.                         40.8
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  1: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.011
#  Model:                            OLS   Adj. R-squared:                  0.005
#  Method:                 Least Squares   F-statistic:                     1.554
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.213
#  Time:                        20:51:05   Log-Likelihood:                -5751.6
#  No. Observations:                 332   AIC:                         1.151e+04
#  Df Residuals:                     329   BIC:                         1.152e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const              1.78e+08   8.54e+06     20.839      0.000    1.61e+08    1.95e+08
#  Month_End_Dummy1 -8.252e+05   1.66e+06     -0.498      0.619   -4.08e+06    2.43e+06
#  ON_Average_Rate  -8.175e+06   4.96e+06     -1.649      0.099   -1.79e+07    1.54e+06
#  ==============================================================================
#  Omnibus:                        5.647   Durbin-Watson:                   0.089
#  Prob(Omnibus):                  0.059   Jarque-Bera (JB):                5.413
#  Skew:                           0.302   Prob(JB):                       0.0668
#  Kurtosis:                       3.160   Cond. No.                         40.9
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  2: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.010
#  Model:                            OLS   Adj. R-squared:                  0.004
#  Method:                 Least Squares   F-statistic:                     1.460
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.234
#  Time:                        20:51:05   Log-Likelihood:                -5751.6
#  No. Observations:                 332   AIC:                         1.151e+04
#  Df Residuals:                     329   BIC:                         1.152e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const              1.78e+08   8.54e+06     20.841      0.000    1.61e+08    1.95e+08
#  Month_End_Dummy2 -4.813e+05   1.43e+06     -0.337      0.736   -3.28e+06    2.32e+06
#  ON_Average_Rate  -8.172e+06   4.96e+06     -1.648      0.099   -1.79e+07    1.55e+06
#  ==============================================================================
#  Omnibus:                        5.713   Durbin-Watson:                   0.089
#  Prob(Omnibus):                  0.057   Jarque-Bera (JB):                5.478
#  Skew:                           0.304   Prob(JB):                       0.0646
#  Kurtosis:                       3.165   Cond. No.                         40.9
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  3: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.010
#  Model:                            OLS   Adj. R-squared:                  0.004
#  Method:                 Least Squares   F-statistic:                     1.383
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.252
#  Time:                        20:51:05   Log-Likelihood:                -5751.7
#  No. Observations:                 332   AIC:                         1.151e+04
#  Df Residuals:                     329   BIC:                         1.152e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             1.779e+08   8.54e+06     20.829      0.000    1.61e+08    1.95e+08
#  Month_End_Dummy3 -2.187e+05   1.29e+06     -0.170      0.865   -2.74e+06     2.3e+06
#  ON_Average_Rate  -8.147e+06   4.96e+06     -1.643      0.100   -1.79e+07    1.57e+06
#  ==============================================================================
#  Omnibus:                        5.742   Durbin-Watson:                   0.089
#  Prob(Omnibus):                  0.057   Jarque-Bera (JB):                5.505
#  Skew:                           0.304   Prob(JB):                       0.0638
#  Kurtosis:                       3.168   Cond. No.                         41.0
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  4: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.010
#  Model:                            OLS   Adj. R-squared:                  0.004
#  Method:                 Least Squares   F-statistic:                     1.357
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.259
#  Time:                        20:51:05   Log-Likelihood:                -5751.7
#  No. Observations:                 332   AIC:                         1.151e+04
#  Df Residuals:                     329   BIC:                         1.152e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             1.779e+08   8.55e+06     20.805      0.000    1.61e+08    1.95e+08
#  Month_End_Dummy4 -1.277e+05    1.2e+06     -0.107      0.915   -2.47e+06    2.22e+06
#  ON_Average_Rate  -8.135e+06   4.96e+06     -1.639      0.101   -1.79e+07    1.59e+06
#  ==============================================================================
#  Omnibus:                        5.758   Durbin-Watson:                   0.088
#  Prob(Omnibus):                  0.056   Jarque-Bera (JB):                5.520
#  Skew:                           0.304   Prob(JB):                       0.0633
#  Kurtosis:                       3.170   Cond. No.                         41.1
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  5: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.010
#  Model:                            OLS   Adj. R-squared:                  0.004
#  Method:                 Least Squares   F-statistic:                     1.343
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.262
#  Time:                        20:51:05   Log-Likelihood:                -5751.7
#  No. Observations:                 332   AIC:                         1.151e+04
#  Df Residuals:                     329   BIC:                         1.152e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             1.779e+08   8.56e+06     20.779      0.000    1.61e+08    1.95e+08
#  Month_End_Dummy5 -7.871e+04   1.13e+06     -0.070      0.945    -2.3e+06    2.14e+06
#  ON_Average_Rate  -8.127e+06   4.97e+06     -1.636      0.102   -1.79e+07    1.61e+06
#  ==============================================================================
#  Omnibus:                        5.758   Durbin-Watson:                   0.088
#  Prob(Omnibus):                  0.056   Jarque-Bera (JB):                5.520
#  Skew:                           0.304   Prob(JB):                       0.0633
#  Kurtosis:                       3.170   Cond. No.                         41.1
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """,
#  6: <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                      y   R-squared:                       0.010
#  Model:                            OLS   Adj. R-squared:                  0.004
#  Method:                 Least Squares   F-statistic:                     1.337
#  Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.264
#  Time:                        20:51:05   Log-Likelihood:                -5751.7
#  No. Observations:                 332   AIC:                         1.151e+04
#  Df Residuals:                     329   BIC:                         1.152e+04
#  Df Model:                           2
#  Covariance Type:                  HC1
#  ====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------------
#  const             1.779e+08   8.56e+06     20.776      0.000    1.61e+08    1.95e+08
#  Month_End_Dummy6 -3.567e+04   1.08e+06     -0.033      0.974   -2.15e+06    2.08e+06
#  ON_Average_Rate  -8.117e+06   4.97e+06     -1.634      0.102   -1.79e+07    1.62e+06
#  ==============================================================================
#  Omnibus:                        5.751   Durbin-Watson:                   0.088
#  Prob(Omnibus):                  0.056   Jarque-Bera (JB):                5.514
#  Skew:                           0.304   Prob(JB):                       0.0635
#  Kurtosis:                       3.170   Cond. No.                         41.2
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors are heteroscedasticity robust (HC1)
#  """}

# %% [markdown]
# **Regressions with Average Repo Outstanding Amount lose significance throughout all consideration windows**

# %%
#Check Again
sm.OLS(d4[d4.index.month!=12]['ON_Total_Volume']/d4[d4.index.month!=12]['ON_N_repos'],
       sm.add_constant(d4[d4.index.month!=12][['Month_End_Dummy','ON_Average_Rate']])).fit(cov_type='HC1').summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.721
# Date:                Mon, 11 Mar 2024   Prob (F-statistic):              0.180
# Time:                        20:51:05   Log-Likelihood:                -5751.5
# No. Observations:                 332   AIC:                         1.151e+04
# Df Residuals:                     329   BIC:                         1.152e+04
# Df Model:                           2
# Covariance Type:                  HC1
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             1.78e+08   8.55e+06     20.831      0.000    1.61e+08    1.95e+08
# Month_End_Dummy  -1.49e+06    2.1e+06     -0.708      0.479   -5.61e+06    2.63e+06
# ON_Average_Rate -8.179e+06   4.96e+06     -1.649      0.099   -1.79e+07    1.54e+06
# ==============================================================================
# Omnibus:                        5.584   Durbin-Watson:                   0.088
# Prob(Omnibus):                  0.061   Jarque-Bera (JB):                5.348
# Skew:                           0.300   Prob(JB):                       0.0690
# Kurtosis:                       3.160   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %%
d4_copia=d4_DecOut.copy()#[d4.copy().index.month!=12]
d4_copia['ON_Avg_Outstanding_Volume']=d4['ON_Total_Volume']/d4['ON_N_repos']

quant_formula = 'ON_Avg_Outstanding_Volume ~ Month_End_Dummy + ON_Average_Rate'
quant_mod = smf.quantreg(quant_formula, d4_copia)
quantiles = [0.05,0.1, 0.25, 0.5, 0.75, 0.90,0.95]  # Quantiles of interest

quant_results = []
for quantile in quantiles:
    quant_result = quant_mod.fit(q=quantile, max_iter=10000)
    quant_results.append(quant_result)

for quantile, quant_result in zip(quantiles, quant_results):
    print(f"Quantile: {quantile}")
    print(quant_result.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning:
#
# Maximum number of iterations (10000) reached.
# Quantile: 0.05
#                              QuantReg Regression Results
# =====================================================================================
# Dep. Variable:     ON_Avg_Outstanding_Volume   Pseudo R-squared:               0.1257
# Model:                              QuantReg   Bandwidth:                   5.023e+06
# Method:                        Least Squares   Sparsity:                    6.922e+07
# Date:                       Mon, 11 Mar 2024   No. Observations:                  332
# Time:                               20:51:10   Df Residuals:                      329
#                                                Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        2.289e+08   1.79e+07     12.799      0.000    1.94e+08    2.64e+08
# Month_End_Dummy -3.495e+06   6.13e+06     -0.571      0.569   -1.55e+07    8.55e+06
# ON_Average_Rate -4.434e+07   1.01e+07     -4.377      0.000   -6.43e+07   -2.44e+07
# ===================================================================================
# Quantile: 0.1
#                              QuantReg Regression Results
# =====================================================================================
# Dep. Variable:     ON_Avg_Outstanding_Volume   Pseudo R-squared:               0.1147
# Model:                              QuantReg   Bandwidth:                   4.438e+06
# Method:                        Least Squares   Sparsity:                    3.033e+07
# Date:                       Mon, 11 Mar 2024   No. Observations:                  332
# Time:                               20:51:10   Df Residuals:                      329
#                                                Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        2.233e+08   1.09e+07     20.427      0.000    2.02e+08    2.45e+08
# Month_End_Dummy  2.108e+05   3.65e+06      0.058      0.954   -6.96e+06    7.38e+06
# ON_Average_Rate -3.899e+07   6.17e+06     -6.321      0.000   -5.11e+07   -2.69e+07
# ===================================================================================
# Quantile: 0.25
#                              QuantReg Regression Results
# =====================================================================================
# Dep. Variable:     ON_Avg_Outstanding_Volume   Pseudo R-squared:              0.06334
# Model:                              QuantReg   Bandwidth:                   4.444e+06
# Method:                        Least Squares   Sparsity:                    2.042e+07
# Date:                       Mon, 11 Mar 2024   No. Observations:                  332
# Time:                               20:51:10   Df Residuals:                      329
#                                                Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        2.091e+08    8.1e+06     25.830      0.000    1.93e+08    2.25e+08
# Month_End_Dummy -6.848e+05   2.79e+06     -0.245      0.806   -6.17e+06     4.8e+06
# ON_Average_Rate -2.893e+07   4.57e+06     -6.329      0.000   -3.79e+07   -1.99e+07
# ===================================================================================
# Quantile: 0.5
#                              QuantReg Regression Results
# =====================================================================================
# Dep. Variable:     ON_Avg_Outstanding_Volume   Pseudo R-squared:              0.03369
# Model:                              QuantReg   Bandwidth:                   4.942e+06
# Method:                        Least Squares   Sparsity:                    1.837e+07
# Date:                       Mon, 11 Mar 2024   No. Observations:                  332
# Time:                               20:51:10   Df Residuals:                      329
#                                                Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         1.89e+08   8.82e+06     21.429      0.000    1.72e+08    2.06e+08
# Month_End_Dummy  1.605e+06   2.82e+06      0.570      0.569   -3.94e+06    7.15e+06
# ON_Average_Rate -1.474e+07   4.99e+06     -2.957      0.003   -2.46e+07   -4.93e+06
# ===================================================================================
# Quantile: 0.75
#                              QuantReg Regression Results
# =====================================================================================
# Dep. Variable:     ON_Avg_Outstanding_Volume   Pseudo R-squared:             0.001302
# Model:                              QuantReg   Bandwidth:                   4.067e+06
# Method:                        Least Squares   Sparsity:                    2.049e+07
# Date:                       Mon, 11 Mar 2024   No. Observations:                  332
# Time:                               20:51:10   Df Residuals:                      329
#                                                Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        1.705e+08   1.04e+07     16.425      0.000     1.5e+08    1.91e+08
# Month_End_Dummy -8.925e+05   2.79e+06     -0.319      0.750   -6.39e+06    4.61e+06
# ON_Average_Rate -1.714e+06   5.88e+06     -0.292      0.771   -1.33e+07    9.85e+06
# ===================================================================================
# Quantile: 0.9
#                              QuantReg Regression Results
# =====================================================================================
# Dep. Variable:     ON_Avg_Outstanding_Volume   Pseudo R-squared:              0.04526
# Model:                              QuantReg   Bandwidth:                   4.735e+06
# Method:                        Least Squares   Sparsity:                    4.910e+07
# Date:                       Mon, 11 Mar 2024   No. Observations:                  332
# Time:                               20:51:10   Df Residuals:                      329
#                                                Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        1.486e+08   1.99e+07      7.463      0.000    1.09e+08    1.88e+08
# Month_End_Dummy -7.257e+06   4.32e+06     -1.678      0.094   -1.58e+07    1.25e+06
# ON_Average_Rate  1.585e+07   1.13e+07      1.404      0.161   -6.35e+06    3.81e+07
# ===================================================================================
# Quantile: 0.95
#                              QuantReg Regression Results
# =====================================================================================
# Dep. Variable:     ON_Avg_Outstanding_Volume   Pseudo R-squared:              0.09712
# Model:                              QuantReg   Bandwidth:                   5.055e+06
# Method:                        Least Squares   Sparsity:                    5.546e+07
# Date:                       Mon, 11 Mar 2024   No. Observations:                  332
# Time:                               20:51:10   Df Residuals:                      329
#                                                Df Model:                            2
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        1.451e+08   1.67e+07      8.668      0.000    1.12e+08    1.78e+08
# Month_End_Dummy -2.681e+06   4.89e+06     -0.548      0.584   -1.23e+07    6.94e+06
# ON_Average_Rate  1.864e+07   9.46e+06      1.970      0.050    2.74e+04    3.73e+07
# ===================================================================================
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/quantile_regression.py:191: IterationLimitWarning:
#
# Maximum number of iterations (10000) reached.

# %% [markdown]
# **Further significance gain by quantile regression focusing on upper quantiles, like 75%, 90% and 95%**

# %% [markdown]
# # Question 5

# %%
d5=pd.DataFrame()
for i in pd.date_range(date(2020,1,1), periods=366):
    t1=df.loc[np.logical_and(df['PurchaseDate']<=i,
                              i<df['RepurchaseDate'])][['CashTakerID','Term','CashAmount']].groupby(['CashTakerID','Term']).sum()

    t2=df.loc[np.logical_and(df['PurchaseDate']<=i,
                              i<df['RepurchaseDate'])][['CashTakerID','Term','CashAmount','Rate']].groupby(['CashTakerID','Term']).apply(
                                  lambda x: np.dot(x['CashAmount']/x['CashAmount'].sum(), x['Rate']).sum() ).rename('Rate')

    t=pd.concat([t1,t2],axis=1)
    t['Date']=i
    t=t.loc[[item[1]=='ON' for item in t.index],:].reset_index()
    d5=pd.concat([d5,t],axis=0)
d5=d5.drop(columns=['Term']).reset_index(drop=True)
#d5=d5.set_index(['CashTakerID','Date'])
d5=pd.merge(d5,
         d5[['Date','CashAmount','Rate']].groupby(['Date']).mean().rename(columns={'CashAmount':'CashAmount_Mean-per-Date',
                                                                                   'Rate':'Rate_Mean-per-Date'}) ,
         how='left', left_index=False, right_index=True, left_on='Date')

# %%
d5
# Out:
#       CashTakerID    CashAmount      Rate       Date  \
# 0               1  1.393000e+09  2.079454 2020-01-04
# 1               2  1.330000e+09  2.002707 2020-01-04
# 2               3  1.700000e+08  1.982941 2020-01-04
# 3               4  4.650000e+08  2.060108 2020-01-04
# 4               5  8.500000e+08  2.258851 2020-01-04
# ...           ...           ...       ...        ...
# 3581            6  1.418377e+08 -0.640865 2020-12-31
# 3582            7  9.097819e+07 -0.024987 2020-12-31
# 3583            8  2.269190e+08 -0.087570 2020-12-31
# 3584            9  3.331143e+08 -0.174851 2020-12-31
# 3585           10  1.917220e+08 -0.642245 2020-12-31
#
#       CashAmount_Mean-per-Date  Rate_Mean-per-Date
# 0                 8.198000e+08            2.097457
# 1                 8.198000e+08            2.097457
# 2                 8.198000e+08            2.097457
# 3                 8.198000e+08            2.097457
# 4                 8.198000e+08            2.097457
# ...                        ...                 ...
# 3581              2.183203e+08           -0.273422
# 3582              2.183203e+08           -0.273422
# 3583              2.183203e+08           -0.273422
# 3584              2.183203e+08           -0.273422
# 3585              2.183203e+08           -0.273422
#
# [3586 rows x 6 columns]

# %%
prova=d5.copy()
prova['CashAmount_Demeaned_Std']=standardize(prova['CashAmount']-prova['CashAmount_Mean-per-Date'])
prova['Rate_Demeaned']=prova['Rate']-prova['Rate_Mean-per-Date']
CashTaker_dummies = pd.get_dummies(prova['CashTakerID'])
X, Y= prova[['CashAmount_Demeaned_Std']].join(CashTaker_dummies.drop(columns=[10])), prova[['Rate_Demeaned']]

# %%
model=sm.OLS(Y, sm.add_constant(X)).fit(cov_type='HC1')

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Rate_Demeaned   R-squared:                       0.347
# Model:                            OLS   Adj. R-squared:                  0.346
# Method:                 Least Squares   F-statistic:                     181.6
# Date:                Mon, 11 Mar 2024   Prob (F-statistic):          6.37e-310
# Time:                        20:51:22   Log-Likelihood:                 2551.2
# No. Observations:                3586   AIC:                            -5080.
# Df Residuals:                    3575   BIC:                            -5012.
# Df Model:                          10
# Covariance Type:                  HC1
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.0702      0.009     -7.509      0.000      -0.089      -0.052
# CashAmount_Demeaned_Std     0.0121      0.002      6.247      0.000       0.008       0.016
# 1                           0.0599      0.011      5.561      0.000       0.039       0.081
# 2                          -0.0065      0.011     -0.597      0.551      -0.028       0.015
# 3                           0.0648      0.011      6.011      0.000       0.044       0.086
# 4                           0.0888      0.011      8.280      0.000       0.068       0.110
# 5                           0.1622      0.012     13.785      0.000       0.139       0.185
# 6                          -0.0130      0.011     -1.156      0.248      -0.035       0.009
# 7                           0.0412      0.010      3.937      0.000       0.021       0.062
# 8                           0.2834      0.011     24.743      0.000       0.261       0.306
# 9                           0.0225      0.011      2.023      0.043       0.001       0.044
# ==============================================================================
# Omnibus:                      218.001   Durbin-Watson:                   2.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              315.038
# Skew:                          -0.525   Prob(JB):                     3.89e-69
# Kurtosis:                       4.003   Cond. No.                         10.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %%
Dummy_Coeff_CI=pd.concat( [model.params.iloc[2:].rename('CashTaker_Dummy_Coeff'),
            model.conf_int(alpha=0.02).rename(columns={0:'1%',1:'99%'}).iloc[2:,:]] ,axis=1)
Dummy_Coeff_CI
# Out:
#    CashTaker_Dummy_Coeff        1%       99%
# 1               0.059896  0.034839  0.084953
# 2              -0.006521 -0.031935  0.018893
# 3               0.064819  0.039733  0.089905
# 4               0.088775  0.063834  0.113717
# 5               0.162213  0.134838  0.189588
# 6              -0.012972 -0.039075  0.013131
# 7               0.041198  0.016853  0.065542
# 8               0.283414  0.256768  0.310061
# 9               0.022462 -0.003371  0.048295

# %%
diff = [h - l for h, l in zip(Dummy_Coeff_CI['99%'], Dummy_Coeff_CI['1%'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=Dummy_Coeff_CI.index, y=Dummy_Coeff_CI['99%'], mode='markers',
                         name='UB(99%)', marker_color='#c92a52', marker_symbol='triangle-down', marker_size=15))
fig.add_trace(go.Scatter(x=Dummy_Coeff_CI.index, y=Dummy_Coeff_CI['CashTaker_Dummy_Coeff'],
                         mode='markers', name='Coefficient', marker_color='black', marker_line_width=1))
fig.add_trace(go.Scatter(x=Dummy_Coeff_CI.index, y=Dummy_Coeff_CI['1%'], mode='markers',
                         name='LB (1%)', marker_color='#4d70c9', marker_symbol='triangle-up', marker_size=15))

fig.add_trace(go.Bar(x=Dummy_Coeff_CI.index, y=diff, base=Dummy_Coeff_CI['1%'], width=0.01, marker_color='black', showlegend=False))
fig.update_layout(template='plotly_white',xaxis_title='Borrower ID',yaxis_title="Competitor's Differential Rate")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6c3f95b7-d5e7-4512-9209-6dc1612981da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c3f95b7-d5e7-4512-9209-6dc1612981da")) {                    Plotly.newPlot(                        "6c3f95b7-d5e7-4512-9209-6dc1612981da",                        [{"marker":{"color":"#c92a52","size":15,"symbol":"triangle-down"},"mode":"markers","name":"UB(99%)","x":[1,2,3,4,5,6,7,8,9],"y":[0.08495320253981266,0.018892610620948633,0.08990456320827314,0.11371678820186557,0.1895884739985376,0.013131456186241331,0.06554222587411924,0.31006063979120524,0.04829522682004144],"type":"scatter"},{"marker":{"color":"black","line":{"width":1}},"mode":"markers","name":"Coefficient","x":[1,2,3,4,5,6,7,8,9],"y":[0.05989618514885,-0.006521021150973756,0.0648189429331144,0.08877520318131364,0.1622131061207741,-0.012971567099349688,0.04119751667536546,0.28341411640346054,0.022462241668578985],"type":"scatter"},{"marker":{"color":"#4d70c9","size":15,"symbol":"triangle-up"},"mode":"markers","name":"LB (1%)","x":[1,2,3,4,5,6,7,8,9],"y":[0.03483916775788734,-0.03193465292289614,0.03973332265795565,0.06383361816076172,0.13483773824301062,-0.03907459038494071,0.016852807476611678,0.25676759301571583,-0.0033707434828834718],"type":"scatter"},{"base":[0.03483916775788734,-0.03193465292289614,0.03973332265795565,0.06383361816076172,0.13483773824301062,-0.03907459038494071,0.016852807476611678,0.25676759301571583,-0.0033707434828834718],"marker":{"color":"black"},"showlegend":false,"width":0.01,"x":[1,2,3,4,5,6,7,8,9],"y":[0.05011403478192532,0.05082726354384477,0.05017124055031749,0.04988317004110385,0.05475073575552697,0.05220604657118204,0.04868941839750757,0.053293046775489405,0.05166597030292491],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth ...
